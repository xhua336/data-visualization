# %%
import pandas
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

# %%
customers=pandas.read_excel(r"Customer list.xlsx")
print(customers)
customers.describe()
print(customers.shape)
print(customers.columns)
print(customers.head())
print(customers.tail())
print(customers.info())
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0      Chickie    Brister    Male                                   86
# 1        Morly     Genery    Male                                   69
# 2      Ardelis  Forrester  Female                                   10
# 3       Lucine      Stutt  Female                                   64
# 4      Melinda     Hadlee  Female                                   34
# ..         ...        ...     ...                                  ...
# 995  Ferdinand  Romanetti    Male                                   60
# 996       Burk    Wortley    Male                                   22
# 997   Melloney      Temby  Female                                   17
# 998     Dickie    Cubbini    Male                                   30
# 999      Sylas    Duffill    Male                                   56
#
#             DOB  Unnamed: 5   Age                     job_title  \
# 0    12-07-1957      1957.0  64.0               General Manager
# 1    12-07-1958      1958.0  63.0           Structural Engineer
# 2    12-07-1959      1959.0  62.0        Senior Cost Accountant
# 3    12-07-1960      1960.0  61.0    Account Representative III
# 4    12-07-1961      1961.0  60.0             Financial Analyst
# ..          ...         ...   ...                           ...
# 995  07-10-1959      1959.0  62.0                     Paralegal
# 996  17-10-2001      2001.0  20.0        Senior Sales Associate
# 997  05-10-1954      1954.0  67.0  Budget/Accounting Analyst IV
# 998  17-12-1952      1952.0  69.0             Financial Advisor
# 999  02-10-1955      1955.0  66.0           Staff Accountant IV
#
#     job_industry_category     wealth_segment deceased_indicator owns_car  \
# 0           Manufacturing      Mass Customer                  N      Yes
# 1                Property      Mass Customer                  N       No
# 2      Financial Services  Affluent Customer                  N       No
# 3           Manufacturing  Affluent Customer                  N      Yes
# 4      Financial Services  Affluent Customer                  N       No
# ..                    ...                ...                ...      ...
# 995    Financial Services  Affluent Customer                  N       No
# 996                Health      Mass Customer                  N       No
# 997    Financial Services  Affluent Customer                  N      Yes
# 998    Financial Services      Mass Customer                  N      Yes
# 999              Property      Mass Customer                  N      Yes
#
#      tenure                   address  postcode state    country  \
# 0        14          45 Shopko Center      4500   QLD  Australia
# 1        16         14 Mccormick Park      2113   NSW  Australia
# 2        10       5 Colorado Crossing      3505   VIC  Australia
# 3         5        207 Annamark Plaza      4814   QLD  Australia
# 4        19         115 Montana Place      2093   NSW  Australia
# ..      ...                       ...       ...   ...        ...
# 995       9               2 Sloan Way      2200   NSW  Australia
# 996       6         04 Union Crossing      2196   NSW  Australia
# 997      15  33475 Fair Oaks Junction      4702   QLD  Australia
# 998      19        57666 Victoria Way      4215   QLD  Australia
# 999      14        21875 Grover Drive      2010   NSW  Australia
#
#      property_valuation  Rank     Value
# 0                     6     1  1.718750
# 1                    11     1  1.718750
# 2                     5     1  1.718750
# 3                     1     4  1.703125
# 4                     9     4  1.703125
# ..                  ...   ...       ...
# 995                   7   996  0.374000
# 996                  10   997  0.357000
# 997                   2   997  0.357000
# 998                   2   997  0.357000
# 999                   9  1000  0.340000
#
# [1000 rows x 20 columns]
# (1000, 20)
# Index(['first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'Unnamed: 5', 'Age',
#        'job_title', 'job_industry_category', 'wealth_segment',
#        'deceased_indicator', 'owns_car', 'tenure', 'address', 'postcode',
#        'state', 'country', 'property_valuation', 'Rank', 'Value'],
#       dtype='object')
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#           DOB  Unnamed: 5   Age                   job_title  \
# 0  12-07-1957      1957.0  64.0             General Manager
# 1  12-07-1958      1958.0  63.0         Structural Engineer
# 2  12-07-1959      1959.0  62.0      Senior Cost Accountant
# 3  12-07-1960      1960.0  61.0  Account Representative III
# 4  12-07-1961      1961.0  60.0           Financial Analyst
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  \
# 0         Manufacturing      Mass Customer                  N      Yes
# 1              Property      Mass Customer                  N       No
# 2    Financial Services  Affluent Customer                  N       No
# 3         Manufacturing  Affluent Customer                  N      Yes
# 4    Financial Services  Affluent Customer                  N       No
#
#    tenure              address  postcode state    country  property_valuation  \
# 0      14     45 Shopko Center      4500   QLD  Australia                   6
# 1      16    14 Mccormick Park      2113   NSW  Australia                  11
# 2      10  5 Colorado Crossing      3505   VIC  Australia                   5
# 3       5   207 Annamark Plaza      4814   QLD  Australia                   1
# 4      19    115 Montana Place      2093   NSW  Australia                   9
#
#    Rank     Value
# 0     1  1.718750
# 1     1  1.718750
# 2     1  1.718750
# 3     4  1.703125
# 4     4  1.703125
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 995  Ferdinand  Romanetti    Male                                   60
# 996       Burk    Wortley    Male                                   22
# 997   Melloney      Temby  Female                                   17
# 998     Dickie    Cubbini    Male                                   30
# 999      Sylas    Duffill    Male                                   56
#
#             DOB  Unnamed: 5   Age                     job_title  \
# 995  07-10-1959      1959.0  62.0                     Paralegal
# 996  17-10-2001      2001.0  20.0        Senior Sales Associate
# 997  05-10-1954      1954.0  67.0  Budget/Accounting Analyst IV
# 998  17-12-1952      1952.0  69.0             Financial Advisor
# 999  02-10-1955      1955.0  66.0           Staff Accountant IV
#
#     job_industry_category     wealth_segment deceased_indicator owns_car  \
# 995    Financial Services  Affluent Customer                  N       No
# 996                Health      Mass Customer                  N       No
# 997    Financial Services  Affluent Customer                  N      Yes
# 998    Financial Services      Mass Customer                  N      Yes
# 999              Property      Mass Customer                  N      Yes
#
#      tenure                   address  postcode state    country  \
# 995       9               2 Sloan Way      2200   NSW  Australia
# 996       6         04 Union Crossing      2196   NSW  Australia
# 997      15  33475 Fair Oaks Junction      4702   QLD  Australia
# 998      19        57666 Victoria Way      4215   QLD  Australia
# 999      14        21875 Grover Drive      2010   NSW  Australia
#
#      property_valuation  Rank  Value
# 995                   7   996  0.374
# 996                  10   997  0.357
# 997                   2   997  0.357
# 998                   2   997  0.357
# 999                   9  1000  0.340
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    object
#  5   Unnamed: 5                           983 non-null    float64
#  6   Age                                  983 non-null    float64
#  7   job_title                            894 non-null    object
#  8   job_industry_category                835 non-null    object
#  9   wealth_segment                       1000 non-null   object
#  10  deceased_indicator                   1000 non-null   object
#  11  owns_car                             1000 non-null   object
#  12  tenure                               1000 non-null   int64
#  13  address                              1000 non-null   object
#  14  postcode                             1000 non-null   int64
#  15  state                                1000 non-null   object
#  16  country                              1000 non-null   object
#  17  property_valuation                   1000 non-null   int64
#  18  Rank                                 1000 non-null   int64
#  19  Value                                1000 non-null   float64
# dtypes: float64(3), int64(5), object(12)
# memory usage: 156.4+ KB
# None

# %%
customers.rename(columns = lambda x: x.replace(' ', '_').replace('-', '_'), inplace=True)
print(customers.columns)
print(customers.isnull().sum(axis=0))




customers.dropna(axis="index",how='any',inplace=True)
print(customers.isnull().sum(axis=0))

#Data mining
kmeans_model=KMeans(n_clusters=3,random_state=1)
good_columns=customers._get_numeric_data()
kmeans_model.fit(good_columns)
labels=kmeans_model.labels_
n_clusters=3

pca_2=PCA(2)
plot_columns=pca_2.fit_transform(good_columns)
plt.scatter(x=plot_columns[:,0], y=plot_columns[:,1], c=labels)
plt.show()
# Out:
# Index(['gender', 'DOB', 'Age', 'job_title', 'job_industry_category',
#        'wealth_segment', 'deceased_indicator', 'owns_car', 'address', 'state',
#        'country', 'property_valuation', 'Rank', 'Value'],
#       dtype='object')
# gender                   0
# DOB                      0
# Age                      0
# job_title                0
# job_industry_category    0
# wealth_segment           0
# deceased_indicator       0
# owns_car                 0
# address                  0
# state                    0
# country                  0
# property_valuation       0
# Rank                     0
# Value                    0
# dtype: int64
# gender                   0
# DOB                      0
# Age                      0
# job_title                0
# job_industry_category    0
# wealth_segment           0
# deceased_indicator       0
# owns_car                 0
# address                  0
# state                    0
# country                  0
# property_valuation       0
# Rank                     0
# Value                    0
# dtype: int64
